# %%
#dependencies
import os
import pandas as pd

import matplotlib.pyplot as plt

# %% [markdown]
# # Importing CSV and Converting to HTML

# %%
#csv path
# csv_path = os.path.join('../WebVisualizations/resources/cities.csv')
csv_path = pd.read_csv('../WebVisualizations/resources/cities.csv')


#create html table and save to file
csv_path.to_html('../WebVisualizations/assets/table.html', index=False)

# %%
weather_df = csv_path
weather_df
# Out:
#      City_ID          City  Cloudiness Country        Date  Humidity    Lat  \
# 0          0  jacareacanga           0      BR  1528902000        62  -6.22
# 1          1    kaitangata         100      NZ  1528905304        94 -46.28
# 2          2      goulburn          20      AU  1528905078        91 -34.75
# 3          3          lata          76      IN  1528905305        89  30.78
# 4          4    chokurdakh           0      RU  1528905306        88  70.62
# ..       ...           ...         ...     ...         ...       ...    ...
# 542      542        scalea          36      IT  1528905631       100  39.82
# 543      543    san andres          68      PH  1528905632       100  13.32
# 544      544        muisne          92      EC  1528905633        84   0.61
# 545      545           ati          20      TD  1528905633        25  13.21
# 546      546      san luis           0      AR  1528905472        53 -33.30
#
#         Lng  Max Temp  Wind Speed
# 0    -57.76     89.60        6.93
# 1    169.85     42.61        5.64
# 2    149.72     44.32       10.11
# 3     78.62     59.89        0.94
# 4    147.90     32.17        2.95
# ..      ...       ...         ...
# 542   15.79     70.06        5.30
# 543  122.68     83.47       22.64
# 544  -80.02     76.90        4.63
# 545   18.34    104.53        4.97
# 546  -66.34     42.43        2.62
#
# [547 rows x 10 columns]

# %% [markdown]
# # Plots (Scatterplots)
# * Latitude Vs Max Temperature
# * Latitude Vs Humidity
# * Latitude Vs Cloudiness
# * Latitude Vs Wind Speed

# %% [markdown]
# # Using a Function for Plots

# %%
#using a function to plot scatter plots

def plotting_data(x_axis, y_axis, x_lab, y_lab, title, savename):
    
    #scatterplot
    plt.scatter(x_axis, y_axis, marker = "o")
    plt.grid(True)

    #labeling
    plt.title(title)
    plt.xlabel(x_lab)
    plt.ylabel(y_lab)
    
    #sizing
    plt.tight_layout
    
    
    #exporting plot as png
    plt.savefig(f"../WebVisualizations/visualizations/{savename}.png")
    
    #printing
    plt.show()

# %% [markdown]
# # Latitude Vs Max Temperature

# %%
#labeling
x_lab = 'Latitude'
y_lab = 'Max Temperature (F)'
title = 'City Latitude vs. Max Temperature'

#saving
savename = 'fig 1 - Latitude_V_Max_Temperature'

#function
plotting_data(weather_df['Lat'], weather_df['Max Temp'], x_lab, y_lab, title, savename)

# %% [markdown]
# # Latitude vs. Humidity Plot

# %%
#labeling
x_lab = 'Latitude'
y_lab = 'Humidity (%)'
title = 'City Latitude vs. Humidity'

#saving
savename = 'fig 2 - Latitude_V_Humidity'

#function
plotting_data(weather_df['Lat'], weather_df['Humidity'], x_lab, y_lab, title, savename)

# %% [markdown]
# # Latitude vs. Cloudiness Plot

# %%
#labeling
x_lab = 'Latitude'
y_lab = 'Cloudiness (%)'
title = 'City Latitude vs. Cloudiness'

#saving
savename = 'fig 3 - Latitude_V_Cloudiness'

#function
plotting_data(weather_df['Lat'], weather_df['Cloudiness'], x_lab, y_lab, title, savename)

# %% [markdown]
# # Latitude vs. Wind Speed Plot

# %%
#labeling
x_lab = 'Latitude'
y_lab = 'wind Speed (mph)'
title = 'City Latitude vs. Wind Speed'

#saving
savename = 'fig 4 - Latitude_V_Wind_speed'

#function
plotting_data(weather_df['Lat'], weather_df['Wind Speed'], x_lab, y_lab, title, savename)
